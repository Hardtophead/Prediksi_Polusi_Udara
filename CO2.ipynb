# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('CO2.csv')
df.plot()
# Out:
# <Axes: >

# %%
df.plot(y='field3', marker='o', linestyle='--', color='red')
plt.ylim(0, 10)
# Out:
# (0.0, 10.0)
